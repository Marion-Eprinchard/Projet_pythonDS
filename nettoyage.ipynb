# %%
import pandas as pd
import numpy as np

# %run donnees.ipynb
# Out:
# /tmp/ipykernel_81819/1727889837.py:25: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lieux_23 = pd.read_csv(url_lieux_23, sep=';', encoding='UTF-8')
# /tmp/ipykernel_81819/1727889837.py:26: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lieux_22 = pd.read_csv(url_lieux_22, sep=';', encoding='UTF-8')

# %%
nouveau_mois = {
    1: "janvier",
    2: "février",
    3: "mars",
    4: "avril",
    5: "mai",
    6: "juin",
    7: "juillet",
    8: "août",
    9: "septembre",
    10: "octobre",
    11: "novembre",
    12: "décembre"
}

nouveau_lum = {
    1:"Plein jour",
    2:"Crépuscule ou aube",
    3:"Nuit sans éclairage public",
    4:"Nuit avec éclairage public non allumé",
    5:"Nuit avec éclairage public allumé"
}

nouveau_int = {
    1:"Hors intersection",
    2:"Intersection en X",
    3:"Intersection en T",
    4:"Intersection en Y",
    5:"Intersection à plus de 4 branches",
    6:"Giratoire",
    7:"Place",
    8:"Passage à niveau",
    9:"Autre intersection"
}

nouveau_atm = {
    -1:"Non renseigné",
    1:"Normale",
    2:"Pluie légère",
    3:"Pluie forte",
    4:"Neige - grêle",
    5:"Brouillard - fumée",
    6:"Vent fort - tempête",
    7:"Temps éblouissant",
    8:"Temps couvert",
    9:"Autre"
}

nouveau_col = {
    -1:"Non renseigné",
    1:"Deux véhicules - frontale",
    2:"Deux véhicules - par l'arrière",
    3:"Deux véhicules - par le côté",
    4:"Trois véhicules - en chaîne",
    5:"Trois véhicules - collisions multiples",
    6:"Autre collision",
    7:"Sans collision"
}

# %%
df_caract_24 = df_caract_24.assign(
    mois=df_caract_24.mois.map(nouveau_mois),
    lum=df_caract_24.lum.map(nouveau_lum),
    int=df_caract_24.int.map(nouveau_int),
    atm=df_caract_24.atm.map(nouveau_atm),
    col=df_caract_24.col.map(nouveau_col)
)

df_caract_24["agg"] = np.where(df_caract_24["agg"] == 1, "Hors agglomération", "En agglomération")

df_caract_24
# Out:
#             Num_Acc  jour      mois    an   hrmn  \
# 0      202400000001    25      mars  2024  07:40
# 1      202400000002    20      mars  2024  15:05
# 2      202400000003    22      mars  2024  19:30
# 3      202400000004    24      mars  2024  17:50
# 4      202400000005    25      mars  2024  19:35
# ...             ...   ...       ...   ...    ...
# 54397  202400054398    10   juillet  2024  02:05
# 54398  202400054399    30  novembre  2024  15:27
# 54399  202400054400    24   octobre  2024  20:40
# 54400  202400054401    30  novembre  2024  15:40
# 54401  202400054402    10   juillet  2024  08:30
#
#                                      lum dep    com                 agg  \
# 0                     Crépuscule ou aube  70  70285  Hors agglomération
# 1                             Plein jour  21  21054    En agglomération
# 2                     Crépuscule ou aube  15  15012  Hors agglomération
# 3                             Plein jour  14  14118    En agglomération
# 4      Nuit avec éclairage public allumé  13  13106  Hors agglomération
# ...                                  ...  ..    ...                 ...
# 54397  Nuit avec éclairage public allumé  94  94065    En agglomération
# 54398                         Plein jour  92  92062    En agglomération
# 54399         Nuit sans éclairage public  29  29068  Hors agglomération
# 54400                         Plein jour  92  92012    En agglomération
# 54401                         Plein jour  94  94028    En agglomération
#
#                      int                 atm  \
# 0      Hors intersection  Brouillard - fumée
# 1      Intersection en T   Temps éblouissant
# 2      Hors intersection             Normale
# 3      Intersection en T   Temps éblouissant
# 4      Intersection en T        Pluie légère
# ...                  ...                 ...
# 54397  Intersection en T        Pluie légère
# 54398  Hors intersection             Normale
# 54399  Hors intersection             Normale
# 54400  Hors intersection             Normale
# 54401  Hors intersection             Normale
#
#                                           col  \
# 0                   Deux véhicules - frontale
# 1                             Autre collision
# 2                             Autre collision
# 3                Deux véhicules - par le côté
# 4      Trois véhicules - collisions multiples
# ...                                       ...
# 54397                         Autre collision
# 54398                         Autre collision
# 54399               Deux véhicules - frontale
# 54400            Deux véhicules - par le côté
# 54401             Trois véhicules - en chaîne
#
#                                            adr          lat          long
# 0                                         D438  47,56277000    6,75832000
# 1                       HOTEL DIEU (RUE DE L')  47,02109000    4,83755000
# 2                           Allée des Tilleuls  44,90238400    2,49641800
# 3                             128 Rue d'Authie  49,19166000   -0,39851000
# 4                       BEDOULE (CHEMIN DE LA)  43,39000000    5,35000000
# ...                                        ...          ...           ...
# 54397                 Avenue Charles Lindbergh  48,75740000    2,34469000
# 54398                        RUE PIERRE GAUDIN  48,88694322    2,24863619
# 54399                          PK 031.950 RN12  48,52619024   -3,96317650
# 54400  JEAN JAURES (BOULEVARD) 63/215 - 70/208  48,83286197    2,24394009
# 54401                   Avenue de la Pompadour  48,78330000    2,46660000
#
# [54402 rows x 15 columns]

# %%
df_caract_23 = df_caract_23.assign(
    mois=df_caract_23.mois.map(nouveau_mois),
    lum=df_caract_23.lum.map(nouveau_lum),
    int=df_caract_23.int.map(nouveau_int),
    atm=df_caract_23.atm.map(nouveau_atm),
    col=df_caract_23.col.map(nouveau_col)
)

df_caract_23["agg"] = np.where(df_caract_23["agg"] == 1, "Hors agglomération", "En agglomération")

df_caract_23
# Out:
#             Num_Acc  jour     mois    an   hrmn  \
# 0      202300000001     7      mai  2023  06:00
# 1      202300000002     7      mai  2023  05:30
# 2      202300000003     7      mai  2023  20:50
# 3      202300000004     6      mai  2023  23:57
# 4      202300000005     7      mai  2023  00:50
# ...             ...   ...      ...   ...    ...
# 54817  202300054818    26  octobre  2023  20:45
# 54818  202300054819    26  octobre  2023  19:10
# 54819  202300054820    26  octobre  2023  09:40
# 54820  202300054821    26  octobre  2023  17:20
# 54821  202300054822    20  octobre  2023  16:30
#
#                                      lum  dep    com                 agg  \
# 0                             Plein jour   75  75101    En agglomération
# 1      Nuit avec éclairage public allumé   94  94080    En agglomération
# 2                             Plein jour   94  94022    En agglomération
# 3      Nuit avec éclairage public allumé   94  94078    En agglomération
# 4      Nuit avec éclairage public allumé   94  94068    En agglomération
# ...                                  ...  ...    ...                 ...
# 54817  Nuit avec éclairage public allumé  974  97416    En agglomération
# 54818         Nuit sans éclairage public  974  97416  Hors agglomération
# 54819                         Plein jour  974  97411    En agglomération
# 54820                         Plein jour  973  97302  Hors agglomération
# 54821                         Plein jour   69  69387    En agglomération
#
#                      int                  atm  \
# 0      Intersection en Y         Pluie légère
# 1      Hors intersection          Pluie forte
# 2      Intersection en T         Pluie légère
# 3      Hors intersection          Pluie forte
# 4      Intersection en X          Pluie forte
# ...                  ...                  ...
# 54817  Hors intersection              Normale
# 54818  Hors intersection              Normale
# 54819  Hors intersection              Normale
# 54820          Giratoire              Normale
# 54821  Hors intersection  Vent fort - tempête
#
#                                           col                           adr  \
# 0                              Sans collision                 RUE DE RIVOLI
# 1                             Autre collision               Avenue de Paris
# 2                   Deux véhicules - frontale     Avenue du Général Leclerc
# 3      Trois véhicules - collisions multiples                  Rue de Paris
# 4                Deux véhicules - par le côté          56bis Avenue Raspail
# ...                                       ...                           ...
# 54817                         Autre collision     LA FONTAINE (RUE JEAN DE)
# 54818            Deux véhicules - par le côté          RN3 (ANCIENNE ROUTE)
# 54819                          Sans collision  BAMBOU (CHEMIN DE LA RUELLE)
# 54820            Deux véhicules - par le côté             ROUTE NATIONALE 1
# 54821            Deux véhicules - par le côté          Boulevard Yves Farge
#
#                  lat           long
# 0        48,86638600     2,32347100
# 1        48,84547782     2,42868146
# 2        48,76240000     2,40655000
# 3        48,73248432     2,44687575
# 4        48,78581000     2,49217000
# ...              ...            ...
# 54817   -21,33828000    55,47771000
# 54818   -21,28865000    55,50994000
# 54819   -20,90129000    55,40598000
# 54820     4,89713000   -52,32854000
# 54821    45,73306000     4,82540000
#
# [54822 rows x 15 columns]

# %%
df_caract_22 = df_caract_22.assign(
    mois=df_caract_22.mois.map(nouveau_mois),
    lum=df_caract_22.lum.map(nouveau_lum),
    int=df_caract_22.int.map(nouveau_int),
    atm=df_caract_22.atm.map(nouveau_atm),
    col=df_caract_22.col.map(nouveau_col)
)

df_caract_22["agg"] = np.where(df_caract_22["agg"] == 1, "Hors agglomération", "En agglomération")

df_caract_22
# Out:
#         Accident_Id  jour     mois    an   hrmn                         lum  \
# 0      202200000001    19  octobre  2022  16:15                  Plein jour
# 1      202200000002    20  octobre  2022  08:34                  Plein jour
# 2      202200000003    20  octobre  2022  17:15                  Plein jour
# 3      202200000004    20  octobre  2022  18:00                  Plein jour
# 4      202200000005    19  octobre  2022  11:45                  Plein jour
# ...             ...   ...      ...   ...    ...                         ...
# 55297  202200055298     1  janvier  2022  03:50  Nuit sans éclairage public
# 55298  202200055299     1  janvier  2022  07:20  Nuit sans éclairage public
# 55299  202200055300     1  janvier  2022  04:27  Nuit sans éclairage public
# 55300  202200055301     1  janvier  2022  08:40                  Plein jour
# 55301  202200055302     1     mars  2022  16:55                  Plein jour
#
#       dep    com                 agg                int            atm  \
# 0      26  26198    En agglomération  Intersection en T        Normale
# 1      25  25204    En agglomération  Intersection en T        Normale
# 2      22  22360    En agglomération          Giratoire        Normale
# 3      16  16102    En agglomération  Intersection en T  Temps couvert
# 4      13  13103  Hors agglomération  Hors intersection        Normale
# ...    ..    ...                 ...                ...            ...
# 55297  2B  2B293  Hors agglomération  Hors intersection        Normale
# 55298  84  84074  Hors agglomération  Hors intersection        Normale
# 55299  74  74001  Hors agglomération  Hors intersection          Autre
# 55300  81  81099  Hors agglomération  Intersection en T        Normale
# 55301  41  41018    En agglomération  Hors intersection        Normale
#
#                                   col                             adr  \
# 0        Deux véhicules - par le côté          TEIL(vieille route du)
# 1        Deux véhicules - par le côté                         Miranda
# 2      Deux véhicules - par l'arrière         ROND POINT DE BREZILLET
# 3                     Autre collision                  LOHMEYER (RUE)
# 4      Deux véhicules - par l'arrière     ROUTE DE JEAN MOULIN-RN 538
# ...                               ...                             ...
# 55297                 Autre collision                             D71
# 55298                 Autre collision                            D973
# 55299                 Autre collision                             D22
# 55300    Deux véhicules - par le côté                   Chemin Toulze
# 55301  Deux véhicules - par l'arrière  RD956 - Pont Charles De Gaulle
#
#                  lat            long
# 0      44,5594200000    4,7257200000
# 1      46,9258100000    6,3462000000
# 2      48,4931620000   -2,7604390000
# 3      45,6926520000   -0,3262900000
# 4      43,6755790366    5,0927031775
# ...              ...             ...
# 55297  42,3101650000    9,4785830000
# 55298  43,7531640000    5,2244760000
# 55299  46,2825320000    6,7328060000
# 55300  43,9272650000    1,9156370000
# 55301  47,5944040000    1,3533290000
#
# [55302 rows x 15 columns]

# %%
nouveau_catr = {
    1: "Autoroute",
    2: "Route nationale",
    3: "Route départementale",
    4: "Voie communale",
    5: "Hors réseau public",
    6: "Parc de stationnement ouvert à la circulation publique",
    7: "Route de métropole urbaine",
    9: "Autre"
}

nouveau_circ = {
    -1: "Non renseigné",
    1: "À sens unique",
    2: "Bidirectionnelle",
    3: "À chaussées séparées",
    4: "Avec voies d'affectation variable"
}

nouveau_vosp = {
    -1: "Non renseigné",
    0: "Sans objet",
    1: "Piste cyclable",
    2: "Bande cyclable",
    3: "Voie réservée"
}

nouveau_prof = {
    -1: "Non renseigné",
    1: "Plat",
    2: "Pente",
    3: "Sommet de côte",
    4: "Bas de côte"
}

nouveau_plan = {
    -1: "Non renseigné",
    1: "Partie rectiligne",
    2: "En courbe à gauche",
    3: "En courbe à droite",
    4: "En « S »"
}

nouveau_surf = {
    -1: "Non renseigné",
    1: "Normale",
    2: "Mouillée",
    3: "Flaques",
    4: "Inondée",
    5: "Enneigée",
    6: "Boue",
    7: "Verglacée",
    8: "Corps gras - Huile",
    9: "Autre"
}

nouveau_infra = {
    -1: "Non renseigné",
    0: "Aucun",
    1: "Souterrain - Tunnel",
    2: "Pont - Autopont",
    3: "Bretelle d'échangeur ou de raccordement",
    4: "Voie ferrée",
    5: "Carrefour aménagé",
    6: "Zone piétonne",
    7: "Zone de péage",
    8: "Chantier",
    9: "Autre"
}

nouveau_situ = {
    -1: "Non renseigné",
    0: "Aucun",
    1: "Sur chaussée",
    2: "Sur bande d'arrêt d'urgence",
    3: "Sur accotement",
    4: "Sur trottoir",
    5: "Sur piste cyclable",
    6: "Sur autre voie spéciale",
    8: "Autre"
}

# %%
df_lieux_24 = df_lieux_24.assign(
    catr=df_lieux_24.catr.map(nouveau_catr),
    circ=df_lieux_24.circ.map(nouveau_circ),
    vosp=df_lieux_24.vosp.map(nouveau_vosp),
    prof=df_lieux_24.prof.map(nouveau_prof),
    plan=df_lieux_24.plan.map(nouveau_plan),
    surf=df_lieux_24.surf.map(nouveau_surf),
    infra=df_lieux_24.infra.map(nouveau_infra),
    situ=df_lieux_24.situ.map(nouveau_situ)
)

df_lieux_24
# Out:
#             Num_Acc                  catr  \
# 0      202400000001  Route départementale
# 1      202400000002        Voie communale
# 2      202400000002        Voie communale
# 3      202400000003        Voie communale
# 4      202400000004        Voie communale
# ...             ...                   ...
# 70243  202400054398  Route départementale
# 70244  202400054399  Route départementale
# 70245  202400054400       Route nationale
# 70246  202400054401  Route départementale
# 70247  202400054402  Route départementale
#
#                                           voie  v1   v2              circ nbv  \
# 0                                         D438   0  NaN  Bidirectionnelle   2
# 1                       HOTEL DIEU (RUE DE L')   0  NaN  Bidirectionnelle   2
# 2                                POTERNE (RUE)   0  NaN     À sens unique   1
# 3                         TILLEULS (ALLEE DES)   0  NaN  Bidirectionnelle   2
# 4           AUTHIE (N° 106 PAIRS -115 IMPAIRS)   0  NaN  Bidirectionnelle   4
# ...                                        ...  ..  ...               ...  ..
# 70243                                      NaN  -1  NaN     À sens unique   1
# 70244                        RUE PIERRE GAUDIN   0  NaN     À sens unique   1
# 70245                                       12   0  NaN     À sens unique   2
# 70246  JEAN JAURES (BOULEVARD) 63/215 - 70/208   0  NaN  Bidirectionnelle   3
# 70247                                       86   0  NaN     À sens unique   2
#
#                  vosp   prof   pr    pr1                plan lartpc larrout  \
# 0          Sans objet   Plat    1    260  En courbe à gauche    NaN       7
# 1          Sans objet   Plat   -1     -1   Partie rectiligne    NaN      -1
# 2          Sans objet   Plat   -1     -1   Partie rectiligne    NaN      -1
# 3          Sans objet   Plat   -1     -1   Partie rectiligne    NaN      -1
# 4          Sans objet   Plat   -1     -1   Partie rectiligne    NaN      -1
# ...               ...    ...  ...    ...                 ...    ...     ...
# 70243   Non renseigné   Plat   -1     -1   Partie rectiligne    NaN      -1
# 70244  Bande cyclable   Plat    0      0  En courbe à gauche    NaN      -1
# 70245      Sans objet  Pente   31  1 000   Partie rectiligne    NaN      10
# 70246      Sans objet   Plat    0      0   Partie rectiligne    NaN    10,5
# 70247      Sans objet  Pente    0      0   Partie rectiligne    NaN      -1
#
#            surf              infra            situ  vma
# 0       Normale              Aucun    Sur chaussée   90
# 1         Autre              Aucun    Sur chaussée   30
# 2         Autre              Aucun    Sur chaussée   30
# 3       Normale              Aucun  Sur accotement   50
# 4       Normale              Autre    Sur chaussée   50
# ...         ...                ...             ...  ...
# 70243  Mouillée  Carrefour aménagé    Sur trottoir   -1
# 70244   Normale              Aucun    Sur chaussée   30
# 70245   Normale              Aucun    Sur chaussée  110
# 70246   Normale              Aucun    Sur chaussée   50
# 70247   Normale    Pont - Autopont    Sur chaussée   50
#
# [70248 rows x 18 columns]

# %%
df_lieux_23 = df_lieux_23.assign(
    catr=df_lieux_23.catr.map(nouveau_catr),
    circ=df_lieux_23.circ.map(nouveau_circ),
    vosp=df_lieux_23.vosp.map(nouveau_vosp),
    prof=df_lieux_23.prof.map(nouveau_prof),
    plan=df_lieux_23.plan.map(nouveau_plan),
    surf=df_lieux_23.surf.map(nouveau_surf),
    infra=df_lieux_23.infra.map(nouveau_infra),
    situ=df_lieux_23.situ.map(nouveau_situ)
)

df_lieux_23
# Out:
#             Num_Acc                  catr  \
# 0      202300000001        Voie communale
# 1      202300000001        Voie communale
# 2      202300000002  Route départementale
# 3      202300000003  Route départementale
# 4      202300000003  Route départementale
# ...             ...                   ...
# 70855  202300054818        Voie communale
# 70856  202300054819        Voie communale
# 70857  202300054820        Voie communale
# 70858  202300054821       Route nationale
# 70859  202300054822        Voie communale
#
#                                            voie  v1   v2              circ  \
# 0                                 RUE DE RIVOLI   0  NaN     À sens unique
# 1                           RUE SAINT FLORENTIN   0  NaN     À sens unique
# 2                                           120   0  NaN  Bidirectionnelle
# 3                                             5   0  NaN  Bidirectionnelle
# 4                                            87   0  NaN  Bidirectionnelle
# ...                                         ...  ..  ...               ...
# 70855                 LA FONTAINE (RUE JEAN DE)   0  NaN  Bidirectionnelle
# 70856                      RN3 (ANCIENNE ROUTE)   0  NaN  Bidirectionnelle
# 70857              BAMBOU (CHEMIN DE LA RUELLE)   0  NaN  Bidirectionnelle
# 70858                         ROUTE NATIONALE 1   0  NaN     Non renseigné
# 70859  YVES FARGES                         (BD)   0  NaN  Bidirectionnelle
#
#       nbv            vosp   prof   pr  pr1                plan lartpc larrout  \
# 0       2      Sans objet   Plat   -1   -1   Partie rectiligne    NaN      -1
# 1       1      Sans objet   Plat   -1   -1   Partie rectiligne    NaN      -1
# 2       3  Bande cyclable   Plat   -1   -1   Partie rectiligne    NaN      -1
# 3       4      Sans objet   Plat    1    0   Partie rectiligne    NaN      -1
# 4       4      Sans objet   Plat    1    0   Partie rectiligne    NaN      -1
# ...    ..             ...    ...  ...  ...                 ...    ...     ...
# 70855   2      Sans objet   Plat   -1    0   Partie rectiligne    NaN      -1
# 70856   2      Sans objet  Pente    0    0   Partie rectiligne    NaN      -1
# 70857   2      Sans objet  Pente    0    0  En courbe à gauche    NaN      -1
# 70858   2  Piste cyclable   Plat    4   50   Partie rectiligne    NaN      -1
# 70859   2  Bande cyclable   Plat   -1   -1   Partie rectiligne    NaN      -1
#
#            surf              infra                situ  vma
# 0      Mouillée              Aucun        Sur chaussée   30
# 1      Mouillée              Aucun        Sur chaussée   30
# 2      Mouillée              Aucun        Sur chaussée   50
# 3      Mouillée  Carrefour aménagé        Sur chaussée   50
# 4      Mouillée  Carrefour aménagé        Sur chaussée   50
# ...         ...                ...                 ...  ...
# 70855   Normale              Aucun        Sur chaussée   50
# 70856   Normale              Aucun        Sur chaussée   50
# 70857   Normale              Aucun               Autre   30
# 70858   Normale              Aucun        Sur chaussée   90
# 70859   Normale              Aucun  Sur piste cyclable   30
#
# [70860 rows x 18 columns]

# %%
df_lieux_22 = df_lieux_22.assign(
    catr=df_lieux_22.catr.map(nouveau_catr),
    circ=df_lieux_22.circ.map(nouveau_circ),
    vosp=df_lieux_22.vosp.map(nouveau_vosp),
    prof=df_lieux_22.prof.map(nouveau_prof),
    plan=df_lieux_22.plan.map(nouveau_plan),
    surf=df_lieux_22.surf.map(nouveau_surf),
    infra=df_lieux_22.infra.map(nouveau_infra),
    situ=df_lieux_22.situ.map(nouveau_situ)
)

df_lieux_22
# Out:
#             Num_Acc                  catr                         voie  v1  \
# 0      202200000001        Voie communale       TEIL(vieille route du)   0
# 1      202200000002        Voie communale                          NaN   0
# 2      202200000003  Route départementale      ROND POINT DE BREZILLET   0
# 3      202200000004        Voie communale    QUATORZE JUILLET (RUE DU)   0
# 4      202200000005  Route départementale  ROUTE DE JEAN MOULIN-RN 538   0
# ...             ...                   ...                          ...  ..
# 55297  202200055298  Route départementale                           71  -1
# 55298  202200055299  Route départementale                          973  -1
# 55299  202200055300  Route départementale                           22   0
# 55300  202200055301  Route départementale                           18  -1
# 55301  202200055302  Route départementale                          NaN  -1
#
#         v2                  circ nbv        vosp   prof   pr  pr1  \
# 0      NaN      Bidirectionnelle   2  Sans objet   Plat  (1)  (1)
# 1      NaN      Bidirectionnelle   2  Sans objet   Plat  (1)  (1)
# 2      NaN         Non renseigné   2  Sans objet   Plat    0    0
# 3      NaN         À sens unique   1  Sans objet  Pente  (1)  (1)
# 4      NaN      Bidirectionnelle   2  Sans objet   Plat    8    0
# ...    ...                   ...  ..         ...    ...  ...  ...
# 55297  NaN      Bidirectionnelle   2  Sans objet  Pente  (1)  (1)
# 55298  NaN      Bidirectionnelle   2  Sans objet   Plat   29    0
# 55299    D      Bidirectionnelle   2  Sans objet   Plat   39  553
# 55300    D      Bidirectionnelle   2  Sans objet   Plat   30  125
# 55301  NaN  À chaussées séparées   4  Sans objet   Plat  (1)  (1)
#
#                      plan lartpc larrout       surf              infra  \
# 0       Partie rectiligne    NaN      -1    Normale              Aucun
# 1       Partie rectiligne    NaN      -1    Normale              Aucun
# 2       Partie rectiligne    NaN      -1    Normale  Carrefour aménagé
# 3       Partie rectiligne    NaN       4    Normale              Aucun
# 4       Partie rectiligne    NaN      -1    Normale              Aucun
# ...                   ...    ...     ...        ...                ...
# 55297   Partie rectiligne    NaN      -1    Normale              Aucun
# 55298  En courbe à gauche    NaN      -1    Normale              Aucun
# 55299  En courbe à gauche    NaN      -1  Verglacée              Aucun
# 55300   Partie rectiligne    NaN      -1    Normale              Aucun
# 55301   Partie rectiligne    NaN       4    Normale              Aucun
#
#                  situ  vma
# 0        Sur chaussée   50
# 1        Sur chaussée   50
# 2        Sur chaussée   50
# 3        Sur chaussée   30
# 4        Sur chaussée   80
# ...               ...  ...
# 55297           Autre   80
# 55298  Sur accotement   80
# 55299  Sur accotement   80
# 55300    Sur chaussée   80
# 55301    Sur chaussée   70
#
# [55302 rows x 18 columns]
